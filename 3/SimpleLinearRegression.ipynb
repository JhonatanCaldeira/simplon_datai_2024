# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split

# %%
X, y = make_regression(n_samples=100, n_features=1, noise=10, random_state=2)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regression.predict(X_test)

# %%
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, regression.predict(X_train), color = 'blue')
plt.title('Train Set')
plt.show()

# %%
plt.scatter(X_test, y_test, color = 'red')
plt.plot(X_train, regression.predict(X_train), color = 'blue')
plt.title('(Test Set)')
plt.show()

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,y_pred,squared=False)
# Out:
# 9.210611359323764

# %%
# X, y = make_regression(n_samples=50, n_features=1, noise=5)
# y = 2*y**3 + 5*y**2 + 10*y + 30
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Input data
X = np.array([30, 35, 40, 45, 50, 55, 60, 65, 70, 75, 80]).reshape((-1, 1))
# Output data
y = np.array([10, 12, 15, 20, 25, 30, 35, 40, 45, 50, 55])
y = 2*y**3 + 50*y**2 + 1.5*y + 30

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()
regression.fit(X,y)
# Out:
# LinearRegression()

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=4)
x_poly = poly_reg.fit_transform(X)
lin_reg = LinearRegression()
lin_reg.fit(x_poly,y)
# Out:
# LinearRegression()

# %%
plt.scatter(X, y, color = 'red')
plt.plot(X, regression.predict(X), color = 'blue')
plt.title('Train Set')
# Out:
# Text(0.5, 1.0, 'Train Set')

# %%
plt.scatter(X, y, color = 'red')
plt.plot(X, lin_reg.predict(poly_reg.fit_transform(X)), color = 'blue')
plt.title('Train Set')
# Out:
# Text(0.5, 1.0, 'Train Set')
