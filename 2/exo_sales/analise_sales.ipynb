# %%
import pandas as pd

# %%
df = pd.read_csv("Commandes.csv")

# %%
df.columns
# Out:
# Index(['ID', ' ID_Client', ' Nom_Client', ' Prenom_Client', ' Adresse_Client',
#        ' Ville_Client', ' Pays_Client', ' Email_Client', ' ID_Commande',
#        ' Date_Commande', ' Montant_Commande', ' ID_Produit', ' Nom_Produit',
#        ' Categorie_Produit', ' Adresse_Magasin', ' Ville_Magasin',
#        ' Pays_Magasin'],
#       dtype='object')

# %%
max(df[' Pays_Magasin'].str.len())
# Out:
# 7

# %%
df[' Adresse_Client'].unique()
# Out:
# array([' 123 Rue de la Paix', ' 456 Avenue des Roses',
#        ' 789 Boulevard du Commerce', ' 567 Avenue des Fleurs',
#        ' 890 Rue Principale', ' 111 Avenue des Étoiles',
#        ' 222 Boulevard des Arts', ' 333 Rue des Sciences',
#        ' 444 Rue des Sports', ' 555 Avenue des Loisirs',
#        ' 666 Rue de la Musique', ' 777 Boulevard de la Nature',
#        " 888 Avenue de l'Artisanat", ' 999 Rue des Jardins',
#        ' 123 Avenue des Voyages', ' 234 Boulevard des Saveurs',
#        " 345 Rue de l'Écologie", ' 456 Avenue des Arts',
#        ' 567 Rue des Plaisirs', ' 678 Avenue des Saveurs',
#        " 789 Rue de l'Écologie", " 890 Avenue de l'Artisanat",
#        ' 111 Avenue des Voyages', ' 222 Boulevard des Saveurs',
#        " 333 Rue de l'Écologie", ' 444 Avenue des Arts',
#        ' 555 Rue des Plaisirs', ' 666 Avenue des Loisirs',
#        ' 888 Rue des Jardins', ' 999 Avenue des Saveurs',
#        " 123 Avenue de l'Artisanat", " 234 Rue de l'Écologie",
# ...

# %%
df
# Out:
#     ID   ID_Client  Nom_Client  Prenom_Client               Adresse_Client
# 0    1           1      Dupont           Jean           123 Rue de la Paix  \
# 1    2           2      Martin          Marie         456 Avenue des Roses
# 2    3           1      Dupont           Jean           123 Rue de la Paix
# 3    4           3     Leclerc         Pierre    789 Boulevard du Commerce
# 4    5           2      Martin          Marie         456 Avenue des Roses
# 5    6           4    Tremblay         Sophie        567 Avenue des Fleurs
# 6    7           5    Lefebvre          André           890 Rue Principale
# 7    8           6       Blanc       Isabelle       111 Avenue des Étoiles
# 8    9           7      Dubois         Michel       222 Boulevard des Arts
# 9   10           8      Moreau          Marie         333 Rue des Sciences
# 10  11           9      Girard        Patrick           444 Rue des Sports
# ...
