# %% [markdown]
# ### Library Import

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("files/covid-hospit-2023-03-31.csv",sep=";")
metadata = pd.read_csv("files/metadonnees-donnees-hospitalieres-covid19.csv",encoding="latin-1",sep=";")
pd.set_option('display.max_colwidth',None)

# %% [markdown]
# ### Metadata and Data

# %%
metadata
# Out:
#     Colonne          Type
# 0       dep        integer  \
# 1      sexe        integer
# 2      jour  string($date)
# 3      hosp        integer
# 4       rea        integer
# 5       rad        integer
# 6        dc        integer
# 7  ssr_usld        integer
# 8  hospconv        integer
# 9   autres         integer
#
#                                                                    Description_FR
# 0                                                                    DÃ©partement  \
# 1                                                                           Sexe
# 2                                                           Date de notification
# 3                                  Nombre de personnes actuellement hospitalisées
# 4  Nombre de personnes actuellement en services de réanimation ou soins intensifs
# 5                                Nombre cumulé de personnes retournées à domicile
# 6                                 Nombre cumulé de personnes décédées à l'hôpital
# 7                     Nombre de personnes actuellement en services de SSR ou USLD
# 8  Nombre de personnes actuellement en services d'hospitalisation conventionnelle
# 9                    Nombre de personnes actuellement en autres types de services
#
#                                                  Description_EN     Exemple
# 0                                                    Department           1
# 1                                                          Sex            0
# 2                                                Date of notice  18/03/2020
# 3                       Number of people currently hospitalized           2
# 4  Number of people currently in resuscitation or critical care           0
# 5                    Total amount of patient that returned home           1
# 6                         Total amout of deaths at the hospital           0
# 7                                                           NaN         NaN
# 8                                                           NaN         NaN
# 9                                                           NaN         NaN

# %%
df.head(10)
# Out:
#   dep  sexe        jour  hosp  rea  HospConv  SSR_USLD  autres  rad  dc
# 0  01     0  2020-03-18     2    0       NaN       NaN     NaN    1   0
# 1  01     1  2020-03-18     1    0       NaN       NaN     NaN    1   0
# 2  01     2  2020-03-18     1    0       NaN       NaN     NaN    0   0
# 3  02     0  2020-03-18    41   10       NaN       NaN     NaN   18  11
# 4  02     1  2020-03-18    19    4       NaN       NaN     NaN   11   6
# 5  02     2  2020-03-18    22    6       NaN       NaN     NaN    7   5
# 6  03     0  2020-03-18     4    0       NaN       NaN     NaN    1   0
# 7  03     1  2020-03-18     1    0       NaN       NaN     NaN    0   0
# 8  03     2  2020-03-18     3    0       NaN       NaN     NaN    1   0
# 9  04     0  2020-03-18     3    1       NaN       NaN     NaN    2   0

# %%
df['jour'] = df['jour'].apply(pd.to_datetime)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\jhona\Desenvolvimento\FormationSimplon\simplon_datai_2024\1\covid_dgsi_mission_bonus.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jhona/Desenvolvimento/FormationSimplon/simplon_datai_2024/1/covid_dgsi_mission_bonus.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> df['jour'] = df['jour'].apply(pd.to_datetime)
#
# File c:\Users\jhona\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:4626, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4516 def apply(
#    4517     self,
#    4518     func: AggFuncType,
#    (...)
#    4521     **kwargs,
#    4522 ) -> DataFrame | Series:
#    4523     """
#    4524     Invoke function on values of Series.
#    4525
#    (...)
#    4624     dtype: float64
#    4625     """
# -> 4626     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File c:\Users\jhona\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:1025, in SeriesApply.apply(self)
#    1022     return self.apply_str()
#    1024 # self.f is Callable
# -> 1025 return self.apply_standard()
#
# File c:\Users\jhona\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:1076, in SeriesApply.apply_standard(self)
#    1074     else:
#    1075         values = obj.astype(object)._values
# -> 1076         mapped = lib.map_infer(
#    1077             values,
#    1078             f,
#    1079             convert=self.convert_dtype,
#    1080         )
#    1082 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1083     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1084     #  See also GH#25959 regarding EA support
#    1085     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\jhona\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# File c:\Users\jhona\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\tools\datetimes.py:1084, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1082         result = convert_listlike(argc, format)
#    1083 else:
# -> 1084     result = convert_listlike(np.array([arg]), format)[0]
#    1085     if isinstance(arg, bool) and isinstance(result, np.bool_):
#    1086         result = bool(result)  # TODO: avoid this kludge.
#
# File c:\Users\jhona\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\tools\datetimes.py:449, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     446 arg = ensure_object(arg)
#     448 if format is None:
# --> 449     format = _guess_datetime_format_for_array(arg, dayfirst=dayfirst)
#     451 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     452 if format is not None and format != "mixed":
#
# File c:\Users\jhona\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\tools\datetimes.py:137, in _guess_datetime_format_for_array(arr, dayfirst)
#     134 if (first_non_null := tslib.first_non_null(arr)) != -1:
#     135     if type(first_non_nan_element := arr[first_non_null]) is str:
#     136         # GH#32264 np.str_ object
# --> 137         guessed_format = guess_datetime_format(
#     138             first_non_nan_element, dayfirst=dayfirst
#     139         )
#     140         if guessed_format is not None:
#     141             return guessed_format
#
# File c:\Users\jhona\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\tslibs\parsing.pyx:957, in pandas._libs.tslibs.parsing.guess_datetime_format()
#
# File c:\Users\jhona\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\tslibs\parsing.pyx:1011, in pandas._libs.tslibs.parsing._fill_token()
#
# File c:\Users\jhona\AppData\Local\Programs\Python\Python311\Lib\re\__init__.py:173, in search(pattern, string, flags)
#     169     """Try to apply the pattern to all of the string, returning
#     170     a Match object, or None if no match was found."""
#     171     return _compile(pattern, flags).fullmatch(string)
# --> 173 def search(pattern, string, flags=0):
#     174     """Scan through string looking for a match to the pattern, returning
#     175     a Match object, or None if no match was found."""
#     176     return _compile(pattern, flags).search(string)
#
# KeyboardInterrupt:

# %% [markdown]
# Retrouver le tableau de donnée "reduced_covid_sexe.csv" à partir des données csv officielle disponible sur le site de data.gouv.fr (pd.groupby?, et pd.unstack?)

# %%
df.drop(['dep','HospConv','SSR_USLD','autres'],axis=1,inplace=True)

# %%
df_group = df.groupby(['jour','sexe']).sum()

# %%
df_group = df_group.unstack(level=-1)

# %%
df_group
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\jhona\Desenvolvimento\FormationSimplon\simplon_datai_2024\1\covid_dgsi_mission_bonus.ipynb Cell 12 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jhona/Desenvolvimento/FormationSimplon/simplon_datai_2024/1/covid_dgsi_mission_bonus.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> df_group.columns.to_series().apply(''.join)
#
# NameError: name 'df_group' is not defined

# %% [markdown]
# Tracer un histogramme permettant de visualiser quelles sont les régions ou la probabilité de mourir du covid en France est la plus élevé ?

# %%
df
